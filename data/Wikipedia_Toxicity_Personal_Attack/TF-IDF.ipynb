# %% [markdown]
# # Prep for TF-IDF

# %%
# Import packages.
from io import BytesIO
from tensorflow.python.lib.io import file_io
import msgpack
import numpy as np
import pandas as pd

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

pd.options.display.max_rows = 4000

# %%
# Read in data.
f = BytesIO(file_io.read_file_to_string('WM-PA-Binary-Data-min-6-votes.bin', binary_mode=True))
data = msgpack.unpack(f, raw=False)

# %%
df = pd.DataFrame(data)

# %%
# Pandas reads the data in with the cols and rows opposite of what we want.
df.head()
# Out:
#                                                    0       \
# label                                                   0
# text    [[this, is, not, creative, .], [those, are, th...
# idx     [[14, 9, 16, 3450, 1], [139, 21, 2, 2165, 2892...
# rev_id                                              37675
#
#                                                    1       \
# label                                                   0
# text    [[the, term, standard, model, is, itself, less...
# idx     [[2, 373, 846, 2004, 9, 558, 452, 635, 97, 8, ...
# rev_id                                              44816
#
#                                                    2       \
# label                                                   0
# text    [[true, or, false, the, situation, as, of, mar...
# idx     [[350, 28, 505, 2, 903, 20, 5, 1073, 2331, 25,...
# rev_id                                              49851
#
#                                                    3       \
# label                                                   0
# text    [[next, maybe, you, could, work, on, being, le...
# idx     [[512, 360, 7, 108, 153, 18, 93, 452, 5839, 24...
# rev_id                                              89320
#
#                                                4       \
# label                                               0
# text    [[this, page, will, need, disambiguation, .]]
# idx                      [[14, 34, 46, 128, 1732, 1]]
# rev_id                                          93890
#
#                                                    5       \
# label                                                   0
# text    [[important, note, for, all, sysops, there, is...
# idx     [[383, 249, 15, 42, 9059, 44, 9, 6, 4994, 12, ...
# rev_id                                             102817
#
#                                                    6       \
# label                                                   0
# text    [[i, removed, the, following, all, names, of, ...
# idx     [[8, 205, 2, 445, 42, 572, 5, 929, 1653, 6405,...
# rev_id                                             103624
#
#                                                    7       \
# label                                                   0
# text    [[if, you, ever, claimed, in, a, judaic, studi...
# idx     [[26, 7, 323, 1240, 12, 6, 20738, 1678, 1529, ...
# rev_id                                             111032
#
#                                                    8       \
# label                                                   0
# text    [[my, apologies, im, english, i, watch, cricke...
# idx     [[30, 2250, 77, 271, 8, 893, 5331, 8, 74, 224,...
# rev_id                                             120283
#
#                                                    9       ...  \
# label                                                   0  ...
# text    [[someone, wrote, more, recognizable, perhaps,...  ...
# idx     [[151, 498, 64, 14320, 386, 9, 6, 795, 5, 41, ...  ...
# rev_id                                             128532  ...
#
#                                                    115831  \
# label                                                   0
# text    [[the, lead, itself, is, original, research, ....
# idx     [[2, 588, 558, 9, 346, 397, 1], [127, 9, 2, 85...
# rev_id                                          699756185
#
#                            115832  \
# label                           0
# text    [[well, done, thanks, !]]
# idx         [[100, 227, 112, 10]]
# rev_id                  699780538
#
#                                                    115833  \
# label                                                   0
# text    [[im, talking, about, you, making, unjustified...
# idx     [[77, 544, 39, 7, 266, 5210, 648, 448, 1], [12...
# rev_id                                          699813325
#
#                                                    115834  \
# label                                                   0
# text    [[yes, from, the, word, guci, or, puci, meanin...
# idx     [[336, 36, 2, 283, 36994, 28, 36994, 805, 5804...
# rev_id                                          699820699
#
#                                                    115835  \
# label                                                   0
# text    [[comment, .], [gentlemen, this, article, prov...
# idx     [[215, 1], [10120, 14, 27, 2073, 31, 4804, 5, ...
# rev_id                                          699822249
#
#                                                    115836  \
# label                                                   0
# text    [[these, sources, dont, exactly, exude, a, sen...
# idx     [[113, 117, 55, 601, 36994, 6, 458, 5, 9090, 1...
# rev_id                                          699848324
#
#                                                    115837  \
# label                                                   0
# text    [[the, institute, for, historical, review, is,...
# idx     [[2, 3105, 15, 849, 443, 9, 6, 1504, 1670, 187...
# rev_id                                          699851288
#
#                                                    115838  \
# label                                                   0
# text    [[the, way, youre, trying, to, describe, it, i...
# idx     [[2, 110, 165, 244, 3, 1322, 13, 12, 14, 27, 9...
# rev_id                                          699857133
#
#                                                    115839  \
# label                                                   0
# text    [[warning, there, is, clearly, a, protectionis...
# idx     [[485, 44, 9, 335, 6, 36994, 3651, 148, 18, 68...
# rev_id                                          699891012
#
#                                                    115840
# label                                                   0
# text    [[alternate, option, is, there, perhaps, enoug...
# idx     [[3845, 2317, 9, 44, 386, 327, 14698, 109, 3, ...
# rev_id                                          699897151
#
# [4 rows x 115841 columns]

# %%
# Transpose df.
transposed_df = df.T
transposed_df.head()
# Out:
#   label                                               text  \
# 0     0  [[this, is, not, creative, .], [those, are, th...
# 1     0  [[the, term, standard, model, is, itself, less...
# 2     0  [[true, or, false, the, situation, as, of, mar...
# 3     0  [[next, maybe, you, could, work, on, being, le...
# 4     0      [[this, page, will, need, disambiguation, .]]
#
#                                                  idx rev_id
# 0  [[14, 9, 16, 3450, 1], [139, 21, 2, 2165, 2892...  37675
# 1  [[2, 373, 846, 2004, 9, 558, 452, 635, 97, 8, ...  44816
# 2  [[350, 28, 505, 2, 903, 20, 5, 1073, 2331, 25,...  49851
# 3  [[512, 360, 7, 108, 153, 18, 93, 452, 5839, 24...  89320
# 4                       [[14, 34, 46, 128, 1732, 1]]  93890

# %%
rev_id = transposed_df[transposed_df['rev_id'] =='5108359']

[print(x) for x in rev_id.text]
[print(x) for x in rev_id.idx]
# Out:
# [['and', 'what', 'is', 'this', 'crew', 'member', 'nonsense', 'youre', 'throwing', 'out', 'on', 'page', 'after', 'page', '?']]
# [None]
# [[4, 41, 9, 14, 4931, 912, 798, 165, 3543, 84, 18, 34, 149, 34, 17]]
# [None]

# %% [markdown]
# ## Detokenize Docs

# %%
# Define function to apply to text column to detokenize the comments.
def detokenize_doc(lists_of_tokens):
    detokenized_doc = []
    for list_of_tokens in lists_of_tokens:
        sentences = ' '.join(list_of_tokens).replace(' , ',',').replace(' .','.').replace(' !','!')
        sentences = sentences.replace(' ?','?').replace(' : ',': ').replace(' \'', '\'')
        detokenized_doc.append(sentences)

    # Flatten. 
    doc = ''
    for sent in detokenized_doc:
        doc += sent + ' '
        
    return doc

# %%
# Concatenate tokens back together into documents for TfidVectorizer.
transposed_df.text = transposed_df.text.apply(detokenize_doc)
transposed_df.head()
# Out:
#                                                  idx label rev_id  \
# 0  [[14, 9, 16, 3450, 1], [139, 21, 2, 2165, 2892...     0  37675
# 1  [[2, 373, 846, 2004, 9, 558, 452, 635, 97, 8, ...     0  44816
# 2  [[350, 28, 505, 2, 903, 20, 5, 1073, 2331, 25,...     0  49851
# 3  [[512, 360, 7, 108, 153, 18, 93, 452, 5839, 24...     0  89320
# 4                       [[14, 34, 46, 128, 1732, 1]]     0  93890
#
#                                                 text
# 0  this is not creative. those are the dictionary...
# 1  the term standard model is itself less npov th...
# 2  true or false the situation as of march 2002 w...
# 3  next maybe you could work on being less condes...
# 4               this page will need disambiguation.

# %%
print(transposed_df.text[0])
# Out:
# this is not creative. those are the dictionary definitions of the terms insurance and ensurance as properly applied to destruction. if you dont understand that fine legitimate criticism ill write up three man cell and bounty hunter and then it will be easy to understand why ensured and insured are different and why both differ from assured. the sentence you quote is absolutely neutral. you just arent familiar with the underlying theory of strike back e. g. submarines as employed in nuclear warfare guiding the insurance nor likely the three man cell structure that kept the ira from being broken by the british. if thats my fault fine i can fix that to explain. but theres nothing personal or creative about it. im tired of arguing with you. re the other article multi party turns up plenty and there is more use of mutually than mutual. if i were to apply your standard id be moving mutual assured destruction to talk for not appealing to a reagan voters biases about its effectiveness and for dropping the ly. there is a double standard in your edits. if it comes from some us history book like peace movement or m. a. d. as defined in 1950 you like it even if the definition is totally useless in 2002 and only of historical interest. if it makes any even obvious connection or implication from the language chosen in multiple profession specific terms you consider it somehow non neutral. gandhi thinks eye for an eye describes riots death penalty and war all at once but you dont. what do you know that gandhi doesnt? guess what reality is not neutral. current use of terms is slightly more controversial. neutrality requires negotiation and some willingness to learn. this is your problem not mine. you may dislike the writing fine that can be fixed. but disregarding fundamental axioms of philosphy with names that recur in multiple phrases or failing to make critical distinctions like insurance versus assurance versus ensurance which are made in one quote by an air force general in an in context quote is just a disservice to the reader. if someone comes here to research a topic like mad they want some context beyond history. if this is a history book fine its a history book. but that wasnt what it was claimed to be.

# %%
csv_path = 'WM-PA-Binary-Data-min-6-votes-TF-IDF.csv'
transposed_df.to_csv(csv_path)
