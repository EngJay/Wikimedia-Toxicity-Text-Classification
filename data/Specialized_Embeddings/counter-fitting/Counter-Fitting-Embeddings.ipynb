# %% [markdown]
# # Prep Wikimedia Data for CF Gao Embeddings

# %%
# Import packages.
from io import BytesIO
from tensorflow.python.lib.io import file_io
import msgpack
import numpy as np
import pandas as pd

# %%
# Get id-to-word dict previously created while generating word embeddings.
f = BytesIO(file_io.read_file_to_string('Gao_PA_id2word.bin', binary_mode=True))
Gao_PA_id2word = msgpack.unpack(f, raw=False)
Gao_PA_id2word_df = pd.DataFrame.from_dict(id2word, orient='index', columns=['id'])
Gao_PA_id2word_df.head()
# Out:
#             id
# 14        this
# 9           is
# 16         not
# 3450  creative
# 1            .

# %%
# Run counter-fitting.
# This produces the enhanced embeddings, which then need to turned back into a numpy array of floats.

# %%
# Read the result back in.
counter_fitted_vocab = pd.read_csv('wikimedia-personal-attacks-200-keyed-counter_fitted_vectors.txt', sep=" ", header=None)

# Check the length of the vocab.
print('vocab size:', len(vocab))
counter_fitted_vocab.head()
# Out:
# vocab size: 36995
#        0         1         2         3         4         5         6    \
# 0    sonja -0.005808 -0.026572 -0.103046 -0.060719  0.094757 -0.007691
# 1     vani  0.034789 -0.088009 -0.047511 -0.016943  0.148968 -0.049160
# 2    woods  0.066142 -0.012744 -0.059821 -0.017741  0.049048  0.096224
# 3  hanging  0.000443 -0.004933 -0.005245 -0.060956  0.063518 -0.019249
# 4    woody  0.067918 -0.001583 -0.149499 -0.037716  0.139094  0.028135
#
#         7         8         9      ...          191       192       193  \
# 0  0.037145 -0.097730 -0.081288    ...    -0.025076  0.008198 -0.134271
# 1  0.029211 -0.036494  0.043149    ...    -0.027269  0.004287 -0.180869
# 2  0.112517 -0.062495 -0.101010    ...     0.016214  0.017011 -0.107387
# 3 -0.053869 -0.026201 -0.075231    ...     0.091328 -0.047149 -0.136224
# 4  0.069009 -0.130570  0.003022    ...    -0.003675  0.068206 -0.136547
#
#         194       195       196       197       198       199       200
# 0 -0.001052  0.035114  0.008318 -0.180306  0.064044  0.058231  0.026130
# 1 -0.111541  0.045441 -0.095603 -0.081328  0.038352  0.128825  0.019857
# 2 -0.047012  0.116589 -0.039114 -0.174756  0.132353  0.062190  0.119502
# 3 -0.053713  0.034217  0.015259 -0.123624  0.048912  0.153850  0.025916
# 4 -0.050590  0.044669 -0.048290 -0.090706  0.085735  0.020854  0.026444
#
# [5 rows x 201 columns]

# %%
# Output is not in same order, use words as index to restore order.
# First, set words as index.
counter_fitted_vocab_reset = counter_fitted_vocab.set_index(0)
counter_fitted_vocab_reset.head()
# Out:
#               1         2         3         4         5         6         7    \
# 0
# sonja   -0.005808 -0.026572 -0.103046 -0.060719  0.094757 -0.007691  0.037145
# vani     0.034789 -0.088009 -0.047511 -0.016943  0.148968 -0.049160  0.029211
# woods    0.066142 -0.012744 -0.059821 -0.017741  0.049048  0.096224  0.112517
# hanging  0.000443 -0.004933 -0.005245 -0.060956  0.063518 -0.019249 -0.053869
# woody    0.067918 -0.001583 -0.149499 -0.037716  0.139094  0.028135  0.069009
#
#               8         9         10     ...          191       192       193  \
# 0                                        ...
# sonja   -0.097730 -0.081288 -0.100188    ...    -0.025076  0.008198 -0.134271
# vani    -0.036494  0.043149 -0.067964    ...    -0.027269  0.004287 -0.180869
# woods   -0.062495 -0.101010 -0.197875    ...     0.016214  0.017011 -0.107387
# hanging -0.026201 -0.075231 -0.088585    ...     0.091328 -0.047149 -0.136224
# woody   -0.130570  0.003022 -0.074498    ...    -0.003675  0.068206 -0.136547
#
#               194       195       196       197       198       199       200
# 0
# sonja   -0.001052  0.035114  0.008318 -0.180306  0.064044  0.058231  0.026130
# vani    -0.111541  0.045441 -0.095603 -0.081328  0.038352  0.128825  0.019857
# woods   -0.047012  0.116589 -0.039114 -0.174756  0.132353  0.062190  0.119502
# hanging -0.053713  0.034217  0.015259 -0.123624  0.048912  0.153850  0.025916
# woody   -0.050590  0.044669 -0.048290 -0.090706  0.085735  0.020854  0.026444
#
# [5 rows x 200 columns]

# %%
# Next, merge the ids from the id2word dict (same one used the create the initial embeddings in text format).
counter_fitted_vocab_reset_merged = pd.merge(counter_fitted_vocab_reset, Gao_PA_id2word_df, left_index=True, right_on='id', how='outer')
counter_fitted_vocab_reset_merged.head()
# Out:
#               1         2         3         4         5         6         7  \
# 12848 -0.005808 -0.026572 -0.103046 -0.060719  0.094757 -0.007691  0.037145
# 36921  0.034789 -0.088009 -0.047511 -0.016943  0.148968 -0.049160  0.029211
# 7405   0.066142 -0.012744 -0.059821 -0.017741  0.049048  0.096224  0.112517
# 6017   0.000443 -0.004933 -0.005245 -0.060956  0.063518 -0.019249 -0.053869
# 13123  0.067918 -0.001583 -0.149499 -0.037716  0.139094  0.028135  0.069009
#
#               8         9        10   ...          192       193       194  \
# 12848 -0.097730 -0.081288 -0.100188   ...     0.008198 -0.134271 -0.001052
# 36921 -0.036494  0.043149 -0.067964   ...     0.004287 -0.180869 -0.111541
# 7405  -0.062495 -0.101010 -0.197875   ...     0.017011 -0.107387 -0.047012
# 6017  -0.026201 -0.075231 -0.088585   ...    -0.047149 -0.136224 -0.053713
# 13123 -0.130570  0.003022 -0.074498   ...     0.068206 -0.136547 -0.050590
#
#             195       196       197       198       199       200       id
# 12848  0.035114  0.008318 -0.180306  0.064044  0.058231  0.026130    sonja
# 36921  0.045441 -0.095603 -0.081328  0.038352  0.128825  0.019857     vani
# 7405   0.116589 -0.039114 -0.174756  0.132353  0.062190  0.119502    woods
# 6017   0.034217  0.015259 -0.123624  0.048912  0.153850  0.025916  hanging
# 13123  0.044669 -0.048290 -0.090706  0.085735  0.020854  0.026444    woody
#
# [5 rows x 201 columns]

# %%
# Verify ids and word are correctly matched.
print(Gao_PA_id2word_df.loc[2, 'id'] + ' = ' + counter_fitted_vocab_reset_merged.loc[2, 'id'])
# Out:
# the = the

# %%
# Restore order by numerical index.
counter_fitted_vocab_reset_merged_sorted = counter_fitted_vocab_reset_merged.sort_index()
counter_fitted_vocab_reset_merged_sorted.head()
# Out:
#           1         2         3         4         5         6         7  \
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2  0.009807  0.010722  0.072162  0.029296  0.096950 -0.051371  0.070996
# 3  0.050796  0.035242 -0.125667  0.037255  0.113678  0.018637 -0.035412
# 4 -0.002296  0.077134 -0.134670 -0.012957  0.070005 -0.003333  0.102417
# 5  0.136606 -0.043707 -0.008443 -0.099816  0.047012  0.100151  0.118435
#
#           8         9        10 ...        192       193       194       195  \
# 1       NaN       NaN       NaN ...        NaN       NaN       NaN       NaN
# 2  0.136207 -0.020015 -0.109610 ...   0.051534  0.053819 -0.050564  0.024532
# 3  0.002932  0.087469  0.056408 ...   0.009613 -0.013976 -0.183031 -0.055258
# 4  0.143010  0.042786 -0.164170 ...  -0.014230 -0.062983 -0.004132 -0.072701
# 5  0.053565  0.074816 -0.087060 ...   0.038696  0.106887 -0.035146 -0.010763
#
#         196       197       198       199       200   id
# 1       NaN       NaN       NaN       NaN       NaN    .
# 2  0.135503 -0.030997 -0.087540 -0.013280  0.019497  the
# 3  0.011709 -0.112704 -0.064617 -0.006286 -0.067656   to
# 4  0.099137 -0.043102  0.098594 -0.018615 -0.027455  and
# 5  0.079028 -0.058162  0.050052  0.057121 -0.001675   of
#
# [5 rows x 201 columns]

# %%
# Drop NaNs.
CF_vocab_reset_merged_sorted_dropped_na = counter_fitted_vocab_reset_merged_sorted.dropna().copy()
print('len(CF_vocab_reset_merged_sorted_dropped_na):', len(CF_vocab_reset_merged_sorted_dropped_na))
CF_vocab_reset_merged_sorted_dropped_na.head()
# Out:
# len(CF_vocab_reset_merged_sorted_dropped_na): 27420
#           1         2         3         4         5         6         7  \
# 2  0.009807  0.010722  0.072162  0.029296  0.096950 -0.051371  0.070996
# 3  0.050796  0.035242 -0.125667  0.037255  0.113678  0.018637 -0.035412
# 4 -0.002296  0.077134 -0.134670 -0.012957  0.070005 -0.003333  0.102417
# 5  0.136606 -0.043707 -0.008443 -0.099816  0.047012  0.100151  0.118435
# 6 -0.013580 -0.079276 -0.126072 -0.022334  0.069643  0.016661  0.039508
#
#           8         9        10 ...        192       193       194       195  \
# 2  0.136207 -0.020015 -0.109610 ...   0.051534  0.053819 -0.050564  0.024532
# 3  0.002932  0.087469  0.056408 ...   0.009613 -0.013976 -0.183031 -0.055258
# 4  0.143010  0.042786 -0.164170 ...  -0.014230 -0.062983 -0.004132 -0.072701
# 5  0.053565  0.074816 -0.087060 ...   0.038696  0.106887 -0.035146 -0.010763
# 6  0.096936  0.023874 -0.094374 ...   0.004717  0.030693  0.018407  0.042755
#
#         196       197       198       199       200   id
# 2  0.135503 -0.030997 -0.087540 -0.013280  0.019497  the
# 3  0.011709 -0.112704 -0.064617 -0.006286 -0.067656   to
# 4  0.099137 -0.043102  0.098594 -0.018615 -0.027455  and
# 5  0.079028 -0.058162  0.050052  0.057121 -0.001675   of
# 6  0.010373  0.082392 -0.073676  0.020993 -0.076747    a
#
# [5 rows x 201 columns]

# %%
# Reset numerical index.
CF_vocab_reset_merged_sorted_dropped_na_reset = CF_vocab_reset_merged_sorted_dropped_na.reset_index()
CF_vocab_reset_merged_sorted_dropped_na_reset.head()
# Out:
#    index         1         2         3         4         5         6  \
# 0      2  0.009807  0.010722  0.072162  0.029296  0.096950 -0.051371
# 1      3  0.050796  0.035242 -0.125667  0.037255  0.113678  0.018637
# 2      4 -0.002296  0.077134 -0.134670 -0.012957  0.070005 -0.003333
# 3      5  0.136606 -0.043707 -0.008443 -0.099816  0.047012  0.100151
# 4      6 -0.013580 -0.079276 -0.126072 -0.022334  0.069643  0.016661
#
#           7         8         9 ...        192       193       194       195  \
# 0  0.070996  0.136207 -0.020015 ...   0.051534  0.053819 -0.050564  0.024532
# 1 -0.035412  0.002932  0.087469 ...   0.009613 -0.013976 -0.183031 -0.055258
# 2  0.102417  0.143010  0.042786 ...  -0.014230 -0.062983 -0.004132 -0.072701
# 3  0.118435  0.053565  0.074816 ...   0.038696  0.106887 -0.035146 -0.010763
# 4  0.039508  0.096936  0.023874 ...   0.004717  0.030693  0.018407  0.042755
#
#         196       197       198       199       200   id
# 0  0.135503 -0.030997 -0.087540 -0.013280  0.019497  the
# 1  0.011709 -0.112704 -0.064617 -0.006286 -0.067656   to
# 2  0.099137 -0.043102  0.098594 -0.018615 -0.027455  and
# 3  0.079028 -0.058162  0.050052  0.057121 -0.001675   of
# 4  0.010373  0.082392 -0.073676  0.020993 -0.076747    a
#
# [5 rows x 202 columns]

# %%
# Drop old index, then shift new index by 1 to accomodate padding.
CF_vocab_reset_merged_sorted_dropped_na_reset.drop(['index'], axis=1, inplace=True)
CF_vocab_reset_merged_sorted_dropped_na_reset.index = CF_vocab_reset_merged_sorted_dropped_na_reset.index + 1  # shifting index
CF_vocab_reset_merged_sorted_dropped_na_reset.head()
# Out:
#           1         2         3         4         5         6         7  \
# 1  0.009807  0.010722  0.072162  0.029296  0.096950 -0.051371  0.070996
# 2  0.050796  0.035242 -0.125667  0.037255  0.113678  0.018637 -0.035412
# 3 -0.002296  0.077134 -0.134670 -0.012957  0.070005 -0.003333  0.102417
# 4  0.136606 -0.043707 -0.008443 -0.099816  0.047012  0.100151  0.118435
# 5 -0.013580 -0.079276 -0.126072 -0.022334  0.069643  0.016661  0.039508
#
#           8         9        10 ...        192       193       194       195  \
# 1  0.136207 -0.020015 -0.109610 ...   0.051534  0.053819 -0.050564  0.024532
# 2  0.002932  0.087469  0.056408 ...   0.009613 -0.013976 -0.183031 -0.055258
# 3  0.143010  0.042786 -0.164170 ...  -0.014230 -0.062983 -0.004132 -0.072701
# 4  0.053565  0.074816 -0.087060 ...   0.038696  0.106887 -0.035146 -0.010763
# 5  0.096936  0.023874 -0.094374 ...   0.004717  0.030693  0.018407  0.042755
#
#         196       197       198       199       200   id
# 1  0.135503 -0.030997 -0.087540 -0.013280  0.019497  the
# 2  0.011709 -0.112704 -0.064617 -0.006286 -0.067656   to
# 3  0.099137 -0.043102  0.098594 -0.018615 -0.027455  and
# 4  0.079028 -0.058162  0.050052  0.057121 -0.001675   of
# 5  0.010373  0.082392 -0.073676  0.020993 -0.076747    a
#
# [5 rows x 201 columns]

# %%
# Drop vectors to get id2word and word2id dicts.
# word2id_df = CF_vocab_reset_merged_sorted_dropped_na_reset.reset_index(inplace=True)
# word2id_df = CF_vocab_reset_merged_sorted_dropped_na_reset.reset_index()

word2id_df = CF_vocab_reset_merged_sorted_dropped_na_reset.set_index('id')

word2id_df = word2id_df[['index']]
word2id_df
# Out:
#              index
# id
# the              1
# to               2
# and              3
# of               4
# a                5
# you              6
# i                7
# is               8
# that             9
# in              10
# it              11
# this            12
# for             13
# not             14
# on              15
# be              16
# as              17
# are             18
# have            19
# your            20
# with            21
# was             22
# if              23
# article         24
# or              25
# but             26
# my              27
# an              28
# wikipedia       29
# by              30
# ...            ...
# renato       27391
# breathy      27392
# argentino    27393
# habs         27394
# sinha        27395
# nagas        27396
# wolter       27397
# shana        27398
# zor          27399
# naidu        27400
# pandey       27401
# wenner       27402
# kips         27403
# tammany      27404
# lon          27405
# toenail      27406
# ringa        27407
# harcourt     27408
# margarine    27409
# neelix       27410
# vani         27411
# mewtwo       27412
# sadako       27413
# denton       27414
# physicality  27415
# rager        27416
# giorgos      27417
# kinshasa     27418
# masterson    27419
# dela         27420
#
# [27420 rows x 1 columns]

# %%
# Create dictionary of just IDs to words.
word2id_dict = word2id_df.to_dict()
word2id_dict = word2id_dict['index']

# Switch keys/values and store word2id dictionary.
# Needed to encode examples.
id2word_dict = {y: x for x, y in id2word_dict.items()}

# %%
# Write word2id list to disk.
with open('Gao_PA_CF_word2id.bin', 'wb') as f:
    msgpack.pack(word2id_dict, f)

# %%
# Write id2word list to disk.
with open('Gao_PA_CF_id2word.bin', 'wb') as f:
    msgpack.pack(id2word_dict, f)

# %%
# Drop col of words.
CF_vocab_reset_merged_sorted_dropped_na_reset.drop(['index', 'id'], axis=1, inplace=True)
CF_vocab_reset_merged_sorted_dropped_na_reset.head()
# Out:
#         1         2         3         4         5         6         7    \
# 0  0.009807  0.010722  0.072162  0.029296  0.096950 -0.051371  0.070996
# 1  0.050796  0.035242 -0.125667  0.037255  0.113678  0.018637 -0.035412
# 2 -0.002296  0.077134 -0.134670 -0.012957  0.070005 -0.003333  0.102417
# 3  0.136606 -0.043707 -0.008443 -0.099816  0.047012  0.100151  0.118435
# 4 -0.013580 -0.079276 -0.126072 -0.022334  0.069643  0.016661  0.039508
#
#         8         9         10     ...          191       192       193  \
# 0  0.136207 -0.020015 -0.109610    ...     0.070672  0.051534  0.053819
# 1  0.002932  0.087469  0.056408    ...    -0.018708  0.009613 -0.013976
# 2  0.143010  0.042786 -0.164170    ...    -0.063995 -0.014230 -0.062983
# 3  0.053565  0.074816 -0.087060    ...     0.077654  0.038696  0.106887
# 4  0.096936  0.023874 -0.094374    ...     0.060960  0.004717  0.030693
#
#         194       195       196       197       198       199       200
# 0 -0.050564  0.024532  0.135503 -0.030997 -0.087540 -0.013280  0.019497
# 1 -0.183031 -0.055258  0.011709 -0.112704 -0.064617 -0.006286 -0.067656
# 2 -0.004132 -0.072701  0.099137 -0.043102  0.098594 -0.018615 -0.027455
# 3 -0.035146 -0.010763  0.079028 -0.058162  0.050052  0.057121 -0.001675
# 4  0.018407  0.042755  0.010373  0.082392 -0.073676  0.020993 -0.076747
#
# [5 rows x 200 columns]

# %%
# Restore padding as first row.
padding = [0.0] * 200
CF_vocab_reset_merged_sorted_dropped_na_reset.loc[-1] = padding  # adding a row
CF_vocab_reset_merged_sorted_dropped_na_reset.index = CF_vocab_reset_merged_sorted_dropped_na_reset.index + 1  # shifting index
CF_vocab_reset_merged_sorted_dropped_na_reset = CF_vocab_reset_merged_sorted_dropped_na_reset.sort_index()  # sorting by index
CF_vocab_reset_merged_sorted_dropped_na_reset.head()
# Out:
#         1         2         3         4         5         6         7    \
# 0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.009807  0.010722  0.072162  0.029296  0.096950 -0.051371  0.070996
# 2  0.050796  0.035242 -0.125667  0.037255  0.113678  0.018637 -0.035412
# 3 -0.002296  0.077134 -0.134670 -0.012957  0.070005 -0.003333  0.102417
# 4  0.136606 -0.043707 -0.008443 -0.099816  0.047012  0.100151  0.118435
#
#         8         9         10     ...          191       192       193  \
# 0  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 1  0.136207 -0.020015 -0.109610    ...     0.070672  0.051534  0.053819
# 2  0.002932  0.087469  0.056408    ...    -0.018708  0.009613 -0.013976
# 3  0.143010  0.042786 -0.164170    ...    -0.063995 -0.014230 -0.062983
# 4  0.053565  0.074816 -0.087060    ...     0.077654  0.038696  0.106887
#
#         194       195       196       197       198       199       200
# 0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1 -0.050564  0.024532  0.135503 -0.030997 -0.087540 -0.013280  0.019497
# 2 -0.183031 -0.055258  0.011709 -0.112704 -0.064617 -0.006286 -0.067656
# 3 -0.004132 -0.072701  0.099137 -0.043102  0.098594 -0.018615 -0.027455
# 4 -0.035146 -0.010763  0.079028 -0.058162  0.050052  0.057121 -0.001675
#
# [5 rows x 200 columns]

# %%
# Add additional word embedding for unknown words.
CF_Gao_vocab = np.concatenate((vocab, np.random.rand(1, 200)))
CF_Gao_vocab
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.4381411 ,  0.1534448 ,  0.11639864, ...,  1.21520825,
#          0.78241566,  0.32214786],
#        [ 0.06929084,  0.07575765,  0.5098544 , ..., -0.61850654,
#         -0.09382881,  0.13775178],
#        ...,
#        [ 0.97458988, -0.67156247, -0.50628575, ...,  0.32488224,
#          1.00972745,  0.02257891],
#        [ 0.09095229,  0.87264827,  0.07317016, ...,  0.86094169,
#          0.86700748,  0.37922492],
#        [ 0.23703329,  0.36283082,  0.71383202, ...,  0.7631847 ,
#          0.83938365,  0.93016998]])

# %%
# Write the damn thing to file.
np.save('wikimedia-PA-CF-200-embeddings', CF_Gao_vocab)

# %%
# Decode comment for validation.
id2word_dict
# Out:
# {1: 'the',
#  2: 'to',
#  3: 'and',
#  4: 'of',
#  5: 'a',
#  6: 'you',
#  7: 'i',
#  8: 'is',
#  9: 'that',
#  10: 'in',
#  11: 'it',
#  12: 'this',
#  13: 'for',
#  14: 'not',
#  15: 'on',
#  16: 'be',
#  17: 'as',
#  18: 'are',
#  19: 'have',
#  20: 'your',
#  21: 'with',
#  22: 'was',
#  23: 'if',
#  24: 'article',
#  25: 'or',
#  26: 'but',
#  27: 'my',
#  28: 'an',
#  29: 'wikipedia',
#  30: 'by',
#  31: 'page',
#  32: 'do',
#  33: 'from',
#  34: 'me',
#  35: 'at',
#  36: 'about',
#  37: 'so',
#  38: 'what',
#  39: 'all',
#  40: 'can',
#  41: 'there',
#  42: 'no',
#  43: 'will',
#  44: 'he',
#  45: 'has',
#  46: 'like',
#  47: 'its',
#  48: 'they',
#  49: 'one',
#  50: 'just',
#  51: 'would',
#  52: 'dont',
#  53: 'which',
#  54: 'please',
#  55: 'who',
#  56: 'any',
#  57: 'been',
#  58: 'we',
#  59: 'should',
#  60: 'his',
#  61: 'more',
#  62: 'some',
#  63: 'other',
#  64: 'talk',
#  65: 'here',
#  66: 'am',
#  67: 'because',
#  68: 'think',
#  69: 'see',
#  70: 'also',
#  71: 'fuck',
#  72: 'people',
#  73: 'im',
#  74: 'why',
#  75: 'up',
#  76: 'how',
#  77: 'only',
#  78: 'were',
#  79: 'out',
#  80: 'when',
#  81: 'edit',
#  82: 'then',
#  83: 'time',
#  84: 'articles',
#  85: 'their',
#  86: 'now',
#  87: 'them',
#  88: 'being',
#  89: 'did',
#  90: 'even',
#  91: 'get',
#  92: 'than',
#  93: 'use',
#  94: 'had',
#  95: 'well',
#  96: 'may',
#  97: 'make',
#  98: 'very',
#  99: 'good',
#  100: 'does',
#  101: 'go',
#  102: 'want',
#  103: 'could',
#  104: 'information',
#  105: 'way',
#  106: 'such',
#  107: 'thanks',
#  108: 'these',
#  109: 'name',
#  110: 'user',
#  111: 'first',
#  112: 'sources',
#  113: 'say',
#  114: 'again',
#  115: 'many',
#  116: 'edits',
#  117: 'source',
#  118: 'made',
#  119: 'section',
#  120: 'new',
#  121: 'wp',
#  122: 'where',
#  123: 'need',
#  124: 'much',
#  125: 'over',
#  126: 'wiki',
#  127: 'really',
#  128: 'same',
#  129: 'right',
#  130: 'most',
#  131: 'pages',
#  132: 'him',
#  133: 'editing',
#  134: 'those',
#  135: 'into',
#  136: 'since',
#  137: 'help',
#  138: 'used',
#  139: 'point',
#  140: 'before',
#  141: 'read',
#  142: 'hi',
#  143: 'going',
#  144: 'after',
#  145: 'discussion',
#  146: 'someone',
#  147: 'said',
#  148: 'work',
#  149: 'find',
#  150: 'still',
#  151: 'fact',
#  152: 'ive',
#  153: 'back',
#  154: 'thank',
#  155: 'own',
#  156: 'two',
#  157: 'something',
#  158: 'stop',
#  159: 'youre',
#  160: 'take',
#  161: 'her',
#  162: 'look',
#  163: 'nigger',
#  164: 'image',
#  165: 'http',
#  166: 'u',
#  167: 'too',
#  168: 'deletion',
#  169: 'faggot',
#  170: 'thats',
#  171: 'blocked',
#  172: 'shit',
#  173: 'history',
#  174: 'deleted',
#  175: 'without',
#  176: 'editors',
#  177: 'add',
#  178: 'never',
#  179: 'yourself',
#  180: 'off',
#  181: 'personal',
#  182: 'vandalism',
#  183: 'suck',
#  184: 'list',
#  185: 'bla',
#  186: 'doesnt',
#  187: 'cant',
#  188: 'she',
#  189: 'another',
#  190: 'added',
#  191: 'link',
#  192: 's',
#  193: 'us',
#  194: 'reason',
#  195: 'put',
#  196: 'against',
#  197: 'removed',
#  198: 'person',
#  199: 'anything',
#  200: 'case',
#  201: 'actually',
#  202: 'hate',
#  203: 'our',
#  204: 'content',
#  205: 'better',
#  206: 'ass',
#  207: 'comment',
#  208: 'seems',
#  209: 'sure',
#  210: 'however',
#  211: 'things',
#  212: 'under',
#  213: 'while',
#  214: 'place',
#  215: 'might',
#  216: 'nothing',
#  217: 'didnt',
#  218: 'both',
#  219: 'done',
#  220: 'part',
#  221: 'believe',
#  222: 'wrong',
#  223: 'style',
#  224: 'thing',
#  225: 'keep',
#  226: 'com',
#  227: 'using',
#  228: 'comments',
#  229: 'ill',
#  230: 'others',
#  231: 'oh',
#  232: 'feel',
#  233: 'question',
#  234: 'free',
#  235: 'trying',
#  236: 'anyone',
#  237: 'little',
#  238: 'links',
#  239: 'world',
#  240: 'note',
#  241: 'policy',
#  242: 'must',
#  243: 'understand',
#  244: 'already',
#  245: 'ask',
#  246: 'change',
#  247: 'though',
#  248: 'years',
#  249: 'long',
#  250: 'give',
#  251: 'above',
#  252: 'problem',
#  253: 'come',
#  254: 'remove',
#  255: 'editor',
#  256: 'fucking',
#  257: 'making',
#  258: 'gay',
#  259: 'last',
#  260: 'life',
#  261: 'issue',
#  262: 'different',
#  263: 'hope',
#  264: 'agree',
#  265: 'fat',
#  266: 'few',
#  267: 'sorry',
#  268: 'admin',
#  269: 'best',
#  270: 'bad',
#  271: 'mean',
#  272: 'every',
#  273: 'word',
#  274: 'let',
#  275: 'rather',
#  276: 'welcome',
#  277: 'doing',
#  278: 'isnt',
#  279: 'users',
#  280: 'reference',
#  281: 'die',
#  282: 'try',
#  283: 'reliable',
#  284: 'state',
#  285: 'post',
#  286: 'down',
#  287: 'hey',
#  288: 'got',
#  289: 'called',
#  290: 'simply',
#  291: 'says',
#  292: 'subject',
#  293: 'real',
#  294: 'day',
#  295: 'penis',
#  296: 'non',
#  297: 'site',
#  298: 'else',
#  299: 'delete',
#  300: 'yet',
#  301: 'www',
#  302: 'text',
#  303: 'war',
#  304: 'opinion',
#  305: 'show',
#  306: 'tell',
#  307: 'great',
#  308: 'ip',
#  309: 'least',
#  310: 'either',
#  311: 'found',
#  312: 'between',
#  313: 'ever',
#  314: 'etc',
#  315: 'probably',
#  316: 'view',
#  317: 'enough',
#  318: 'references',
#  319: 'far',
#  320: 'matter',
#  321: 'evidence',
#  322: 'id',
#  323: 'e',
#  324: 'clearly',
#  325: 'yes',
#  326: 'leave',
#  327: 'around',
#  328: 'org',
#  329: 'through',
#  330: 'example',
#  331: 'consensus',
#  332: 'top',
#  333: 'saying',
#  334: 'original',
#  335: 'cunt',
#  336: 'language',
#  337: 'color',
#  338: 'true',
#  339: 'thought',
#  340: 'given',
#  341: 'old',
#  342: 'jew',
#  343: 'pov',
#  344: 'account',
#  345: 'questions',
#  346: 'support',
#  347: 'revert',
#  348: 'maybe',
#  349: 'having',
#  350: 'request',
#  351: 'clear',
#  352: 'needs',
#  353: 'continue',
#  354: 'love',
#  355: 'instead',
#  356: 'claim',
#  357: 'written',
#  358: 'times',
#  359: 'until',
#  360: 'term',
#  361: 'always',
#  362: 'number',
#  363: 'write',
#  364: 'lot',
#  365: 'dick',
#  366: 'correct',
#  367: 'material',
#  368: 'states',
#  369: 'important',
#  370: 'seem',
#  371: 'facts',
#  372: 'perhaps',
#  373: 'title',
#  374: 'based',
#  375: 're',
#  376: 'attack',
#  377: 'further',
#  378: 'reverted',
#  379: 'check',
#  380: 'tag',
#  381: 'care',
#  382: 'research',
#  383: 'words',
#  384: 'makes',
#  385: 'fair',
#  386: 'mention',
#  387: 'rules',
#  388: 'quite',
#  389: 'background',
#  390: 'message',
#  391: 'man',
#  392: 'once',
#  393: 'notable',
#  394: 'left',
#  395: 'american',
#  396: 'created',
#  397: 'adding',
#  398: 'whether',
#  399: 'bit',
#  400: 'three',
#  401: 'cannot',
#  402: 'version',
#  403: 'idea',
#  404: 'hello',
#  405: 'means',
#  406: 'big',
#  407: 'year',
#  408: 'several',
#  409: 'theres',
#  410: 'copyright',
#  411: 'each',
#  412: 'website',
#  413: 'encyclopedia',
#  414: 'call',
#  415: 'bitch',
#  416: 'known',
#  417: 'en',
#  418: 'd',
#  419: 'consider',
#  420: 'whole',
#  421: 'images',
#  422: 'kind',
#  423: 'considered',
#  424: 'second',
#  425: 'group',
#  426: 'align',
#  427: 'review',
#  428: 'current',
#  429: 'following',
#  430: 'course',
#  431: 'mentioned',
#  432: 'changes',
#  433: 'live',
#  434: 'statement',
#  435: 'seen',
#  436: 'less',
#  437: 'moron',
#  438: 'media',
#  439: 'topic',
#  440: 'speedy',
#  441: 'end',
#  442: 'sense',
#  443: 'start',
#  444: 'possible',
#  445: 'issues',
#  446: 'including',
#  447: 'claims',
#  448: 'regarding',
#  449: 'away',
#  450: 'removing',
#  451: 'include',
#  452: 'address',
#  453: 'general',
#  454: 'days',
#  455: 'ok',
#  456: 'attacks',
#  457: 'main',
#  458: 'desu',
#  459: 'community',
#  460: 'anyway',
#  461: 'myself',
#  462: 'related',
#  463: 'info',
#  464: 'wont',
#  465: 'truth',
#  466: 'contributions',
#  467: 'suggest',
#  468: 'warning',
#  469: 'stupid',
#  470: 'neutral',
#  471: 'news',
#  472: 'template',
#  473: 'explain',
#  474: 'line',
#  475: 'listed',
#  476: 'power',
#  477: 'guys',
#  478: 'anti',
#  479: 'public',
#  480: 'god',
#  481: 'wrote',
#  482: 'school',
#  483: 'faith',
#  484: 'everyone',
#  485: 'changed',
#  486: 'notice',
#  487: 'mind',
#  488: 'false',
#  489: 'provide',
#  490: 'order',
#  491: 'hes',
#  492: 'piece',
#  493: 'self',
#  494: 'next',
#  495: 'later',
#  496: 'official',
#  497: 'taken',
#  498: 'jews',
#  499: 'nice',
#  500: 'date',
#  501: 'report',
#  502: 'freedom',
#  503: 'sentence',
#  504: 'completely',
#  505: 'vertical',
#  506: 'picture',
#  507: 'redirect',
#  508: 'guidelines',
#  509: 'full',
#  510: 'single',
#  511: 'due',
#  512: 'youve',
#  513: 'country',
#  514: 'started',
#  515: 'within',
#  516: 'although',
#  517: 'relevant',
#  518: 'per',
#  519: 'looking',
#  520: 'sucks',
#  521: 'interest',
#  522: 'stuff',
#  523: 'p',
#  524: 'talking',
#  525: 'common',
#  526: 'during',
#  527: 'especially',
#  528: 'dickhead',
#  529: 'according',
#  530: 'wanker',
#  531: 'answer',
#  532: 'wasnt',
#  533: 'everything',
#  534: 'obviously',
#  535: 'included',
#  536: 'political',
#  537: 'party',
#  538: 'itself',
#  539: 'c',
#  540: 'wanted',
#  541: 'discuss',
#  542: 'move',
#  543: 'banned',
#  544: 't',
#  545: 'appropriate',
#  546: 'came',
#  547: 'project',
#  548: 'border',
#  549: 'books',
#  550: 'reading',
#  551: 'happy',
#  552: 'names',
#  553: 'recent',
#  554: 'british',
#  555: 'middle',
#  556: 'whatever',
#  557: 'writing',
#  558: 'fag',
#  559: 'create',
#  560: 'certainly',
#  561: 'aids',
#  562: 'involved',
#  563: 'nor',
#  564: 'posted',
#  565: 'pretty',
#  566: 'able',
#  567: 'wish',
#  568: 'hard',
#  569: 'government',
#  570: 'therefore',
#  571: 'high',
#  572: 'category',
#  573: 'response',
#  574: 'ban',
#  575: 'guy',
#  576: 'unless',
#  577: 'exactly',
#  578: 'deleting',
#  579: 'google',
#  580: 'specific',
#  581: 'nipple',
#  582: 'currently',
#  583: 'criteria',
#  584: 'past',
#  585: 'argument',
#  586: 'reasons',
#  587: 'four',
#  588: 'published',
#  589: 'ago',
#  590: 'asked',
#  591: 'small',
#  592: 'huge',
#  593: 'administrator',
#  594: 'cock',
#  595: 'game',
#  596: 'pro',
#  597: 'side',
#  598: 'white',
#  599: 'system',
#  600: 'rule',
#  601: 'policies',
#  602: 'position',
#  603: 'b',
#  604: 'reverting',
#  605: 'today',
#  606: 'sign',
#  607: 'form',
#  608: 'looks',
#  609: 'large',
#  610: 'edited',
#  611: 'present',
#  612: 'dispute',
#  613: 'kill',
#  614: 'interested',
#  615: 'united',
#  616: 'alone',
#  617: 'quote',
#  618: 'guess',
#  619: 'knowledge',
#  620: 'appears',
#  621: 'major',
#  622: 'tried',
#  623: 'future',
#  624: 'national',
#  625: 'stated',
#  626: 'summary',
#  627: 'havent',
#  628: 'law',
#  629: 'remember',
#  630: 'mr',
#  631: 'access',
#  632: 'along',
#  633: 'jpg',
#  634: 'black',
#  635: 'padding',
#  636: 'often',
#  637: 'ones',
#  638: 'city',
#  639: 'similar',
#  640: 'proof',
#  641: 'paragraph',
#  642: 'stay',
#  643: 'width',
#  644: 'took',
#  645: 'entry',
#  646: 'film',
#  647: 'shows',
#  648: 'lets',
#  649: 'told',
#  650: 'entire',
#  651: 'solid',
#  652: 'hell',
#  653: 'become',
#  654: 'needed',
#  655: 'provided',
#  656: 'bias',
#  657: 'views',
#  658: 'otherwise',
#  659: 'family',
#  660: 'almost',
#  661: 'certain',
#  662: 'learn',
#  663: 'themselves',
#  664: 'working',
#  665: 'taking',
#  666: 'actions',
#  667: 'process',
#  668: 'open',
#  669: 'particular',
#  670: 'internet',
#  671: 'theory',
#  672: 'file',
#  673: 'f',
#  674: 'g',
#  675: 'sort',
#  676: 'respect',
#  677: 'cited',
#  678: 'points',
#  679: 'problems',
#  680: 'search',
#  681: 'faggots',
#  682: 'story',
#  683: 'allowed',
#  684: 'obvious',
#  685: 'useful',
#  686: 'asshole',
#  687: 'death',
#  688: 'web',
#  689: 'whats',
#  690: 'super',
#  691: 'regards',
#  692: 'fine',
#  693: 'actual',
#  694: 'human',
#  695: 'definition',
#  696: 'biased',
#  697: 'below',
#  698: 'terms',
#  699: 'thus',
#  700: 'unblock',
#  701: 'simple',
#  702: 'attention',
#  703: 'indeed',
#  704: 'short',
#  705: 'follow',
#  706: 'reply',
#  707: 'appear',
#  708: 'john',
#  709: 'himself',
#  710: 'hand',
#  711: 'freezer',
#  712: 'smells',
#  713: 'arent',
#  714: 'noticed',
#  715: 'calling',
#  716: 'wouldnt',
#  717: 'music',
#  718: 'administrators',
#  719: 'appreciate',
#  720: 'jewish',
#  721: 'university',
#  722: 'act',
#  723: 'various',
#  724: 'members',
#  725: 'german',
#  726: 'interesting',
#  727: 'area',
#  728: 'cite',
#  729: 'uk',
#  730: 'seriously',
#  731: 'likely',
#  732: 'set',
#  733: 'company',
#  734: 'aware',
#  735: 'citation',
#  736: 'greek',
#  737: 'hours',
#  738: 'damn',
#  739: 'deal',
#  740: 'saw',
#  741: 'hitler',
#  742: 'five',
#  743: 'status',
#  744: 'shouldnt',
#  745: 'blocking',
#  746: 'upon',
#  747: 'criticism',
#  748: 'longer',
#  749: 'comes',
#  750: 'valid',
#  751: 'anonymous',
#  752: 'happened',
#  753: 'author',
#  754: 'serious',
#  755: 'm',
#  756: 'type',
#  757: 'statements',
#  758: 'x',
#  759: 'nonsense',
#  760: 'result',
#  761: 'action',
#  762: 'fish',
#  763: 'went',
#  764: 'attempt',
#  765: 'explanation',
#  766: 'meaning',
#  767: 'homo',
#  768: 'job',
#  769: 'cause',
#  770: 'mother',
#  771: 'rights',
#  772: 'previous',
#  773: 'improve',
#  774: 'week',
#  775: 'goes',
#  776: 'context',
#  777: 'opinions',
#  778: 'personally',
#  779: 'conflict',
#  780: 'soon',
#  781: 'science',
#  782: 'class',
#  783: 'yeah',
#  784: 'together',
#  785: 'teabag',
#  786: 'disagree',
#  787: 'email',
#  788: 'record',
#  789: 'recently',
#  790: 'moved',
#  791: 'behavior',
#  792: 'third',
#  793: 'works',
#  794: 'shall',
#  795: 'bastard',
#  796: 'none',
#  797: 'placed',
#  798: 'prove',
#  799: 'church',
#  800: 'generally',
#  801: 'exist',
#  802: 'citations',
#  803: 'idiot',
#  804: 'boy',
#  805: 'standard',
#  806: 'external',
#  807: 'historical',
#  808: 'proper',
#  809: 'accept',
#  810: 'series',
#  811: 'months',
#  812: 'available',
#  813: 'head',
#  814: 'complete',
#  815: 'level',
#  816: 'accurate',
#  817: 'description',
#  818: 'shut',
#  819: 'heard',
#  820: 'rest',
#  821: 'theyre',
#  822: 'lol',
#  823: 'legal',
#  824: 'asking',
#  825: 'assume',
#  826: 'decide',
#  827: 'computer',
#  828: 'culture',
#  829: 'addition',
#  830: 'violation',
#  831: 'band',
#  832: 'size',
#  833: 'sock',
#  834: 'friends',
#  835: 'sites',
#  836: 'doubt',
#  837: 'eat',
#  838: 'living',
#  839: 'lack',
#  840: 'south',
#  841: 'contact',
#  842: 'copy',
#  843: 'cheers',
#  844: 'html',
#  845: 'gets',
#  846: 'run',
#  847: 'sections',
#  848: 'de',
#  849: 'avoid',
#  850: 'watch',
#  851: 'enjoy',
#  852: 'okay',
#  853: 'video',
#  854: 'reported',
#  855: 'abuse',
#  856: 'sandbox',
#  857: 'speak',
#  858: 'among',
#  859: 'situation',
#  860: 'apparently',
#  861: 'outside',
#  862: 'difference',
#  863: 'data',
#  864: 'necessary',
#  865: 'friend',
#  866: 'except',
#  867: 'member',
#  868: 'countries',
#  869: 'username',
#  870: 'india',
#  871: 'debate',
#  872: 'million',
#  873: 'period',
#  874: 'space',
#  875: 'vandalize',
#  876: 'control',
#  877: 'fix',
#  878: 'multiple',
#  879: 'supposed',
#  880: 'separate',
#  881: 'contributing',
#  882: 'purpose',
#  883: 'early',
#  884: 'military',
#  885: 'v',
#  886: 'christian',
#  887: 'meant',
#  888: 'modern',
#  889: 'youll',
#  890: 'groups',
#  891: 'bot',
#  892: 'w',
#  893: 'half',
#  894: 'born',
#  895: 'civil',
#  896: 'messages',
#  897: 'team',
#  898: 'usually',
#  899: 'details',
#  900: 'lost',
#  901: 'o',
#  902: 'takes',
#  903: 'quality',
#  904: 'special',
#  905: 'close',
#  906: 'allow',
#  907: 'fucker',
#  908: 'worked',
#  909: 'n',
#  910: 'happen',
#  911: 'court',
#  912: 'contribute',
#  913: 'tv',
#  914: 'religion',
#  915: 'face',
#  916: 'totally',
#  917: 'july',
#  918: 'coming',
#  919: 'disruptive',
#  920: 'majority',
#  921: 'wait',
#  922: 'warring',
#  923: 'incorrect',
#  924: 'refer',
#  925: 'absolutely',
#  926: 'proposed',
#  927: 'standards',
#  928: 'giving',
#  929: 'accepted',
#  930: 'population',
#  931: 'gave',
#  932: 'tags',
#  933: 'worth',
#  934: 'fan',
#  935: 'sexual',
#  936: 'significant',
#  937: 'reality',
#  938: 'merely',
#  939: 'couple',
#  940: 'directly',
#  941: 'international',
#  942: 'spam',
#  943: 'changing',
#  944: 'creating',
#  945: 'religious',
#  946: 'posting',
#  947: 'readers',
#  948: 'house',
#  949: 'dead',
#  950: 'test',
#  951: 'bring',
#  952: 'r',
#  953: 'racist',
#  954: 'peoples',
#  955: 'wants',
#  956: 'scientific',
#  957: 'uses',
#  958: 'earlier',
#  959: 'song',
#  960: 'force',
#  961: 'bitches',
#  962: 'character',
#  963: 'business',
#  964: 'vandal',
#  965: 'home',
#  966: 'nazi',
#  967: 'posts',
#  968: 'specifically',
#  969: 'israel',
#  970: 'online',
#  971: 'nobody',
#  972: 'arguments',
#  973: 'dear',
#  974: 'numbers',
#  975: 'diff',
#  976: 'wales',
#  977: 'red',
#  978: 'lies',
#  979: 'press',
#  980: 'french',
#  981: 'helpful',
#  982: 'bullshit',
#  983: 'north',
#  984: 'men',
#  985: 'king',
#  986: 'highly',
#  987: 'behind',
#  988: 'body',
#  989: 'pictures',
#  990: 'preceding',
#  991: 'knows',
#  992: 'former',
#  993: 'cases',
#  994: 'propaganda',
#  995: 'weeks',
#  996: 'decided',
#  997: 'named',
#  998: 'neither',
#  999: 'primary',
#  1000: 'poor',
#  ...}
